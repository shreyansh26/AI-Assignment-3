# %% [markdown]
# # Assignment 3 - Logistic Regression
#
# Given the marks of a student in two subjects we want to predict whether he will get admission or not.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from model import *
from utils import *

# %%
file = 'marks.csv'

# %%
X, Y, admitted, not_admitted = load_data(file)

# %% [markdown]
# ### Visualize dataset

# %%
visualize_data(admitted, not_admitted)

# %% [markdown]
# ### Train the model

# %%
# Try changing the learning rate and number of iterations

##################
lr = None
num_iter = None
##################

model = Logistic_Regression() 
model.train(X, Y, lr,num_iter,10)
print("Model Accuracy: {}".format(model.accuracy(X,Y)))
# Out:
# Iteration 0 of 100000. Loss: 69.314718 LR: 0.000010
# Iteration 10000 of 100000. Loss: 69.347457 LR: 0.000010
# Iteration 20000 of 100000. Loss: 70.161354 LR: 0.000010
# Iteration 30000 of 100000. Loss: 71.218252 LR: 0.000010
# Iteration 40000 of 100000. Loss: 72.445855 LR: 0.000010
# Iteration 50000 of 100000. Loss: 73.788751 LR: 0.000010
# Iteration 60000 of 100000. Loss: 75.205538 LR: 0.000010
# Iteration 70000 of 100000. Loss: 76.665818 LR: 0.000010
# Iteration 80000 of 100000. Loss: 78.147548 LR: 0.000010
# Iteration 90000 of 100000. Loss: 79.634899 LR: 0.000010
# Model Accuracy: 0.91

# %% [markdown]
# ### Visualize Decision Boundary

# %%
visualize_decision_boundary(admitted, not_admitted, X, model.weights.flatten())

# %% [markdown]
# ### Save hyperparameters

# %%
save_hyperparameters(lr, num_iter)
